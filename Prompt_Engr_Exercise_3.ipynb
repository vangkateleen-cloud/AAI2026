# %% [markdown]
# <a href="https://colab.research.google.com/github/vangkateleen-cloud/AAI2026/blob/dev/Prompt_Engr_Exercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3 — Self-Reflection Prompt (Critique and Revise)
#
# ## Goal
# Demonstrate self-reflection prompting where the AI critiques its own output against explicit criteria and produces an improved version.
#
# ---
#
# ## Original Summary (Before)
#
# "The product is good and works well. Customers like it. Improvements needed."
#
# ---
#
# ## Self-Reflection Prompt
#
# System:
# You are a senior editor reviewing a product summary intended for product managers.
#
# You must evaluate the summary against the following explicit criteria:
#
# 1. Accuracy — Does it provide factual or measurable information?
# 2. Specificity — Does it avoid vague adjectives (e.g., "good", "nice")?
# 3. Audience alignment — Is it written for product managers?
# 4. Length constraint — Maximum 60 words.
# 5. Formatting requirement — Must use bullet points.
# 6. Actionability — Must include at least one concrete next step.
#
# Instructions:
# Step 1 — Critique the original summary using each criterion above.
# Step 2 — Provide a revised version that satisfies all criteria.
# Step 3 — Explain exactly what changes were made and why.
#
# Do not skip any steps.

# %%
# Simulated AI self-reflection process

original_summary = "The product is good and works well. Customers like it. Improvements needed."

print("=== BEFORE SUMMARY ===")
print(original_summary)


# Step 1 — Critique
critique = {
    "Accuracy": "No measurable data or performance metrics provided.",
    "Specificity": "Uses vague adjective 'good' with no detail.",
    "Audience Alignment": "Not tailored to product managers or strategic decisions.",
    "Length Constraint": "Within limit, but lacks meaningful content.",
    "Formatting Requirement": "Not formatted as bullet points.",
    "Actionability": "No specific next steps mentioned."
}

print("\n=== CRITIQUE ===")
for k, v in critique.items():
    print(f"{k}: {v}")


# Step 2 — Revised Version (meets all constraints)
improved_summary = """
- Product achieved 99.2% uptime last quarter, exceeding SLA targets.
- Net Promoter Score improved to +25, indicating strong user satisfaction.
- Primary feedback highlights onboarding friction and mobile performance gaps.
- Next step: prioritize onboarding redesign and measure conversion lift.
"""

print("\n=== AFTER SUMMARY ===")
print(improved_summary)


# Step 3 — Explicit Change Explanation
print("\n=== CHANGES MADE ===")
print("1. Replaced vague wording ('good') with measurable performance metrics.")
print("2. Reformatted into structured bullet points for executive readability.")
print("3. Added actionable next step aligned to product management decisions.")
print("4. Tailored tone and content to a product manager audience.")
# Out:
# === BEFORE SUMMARY ===
# The product is good and works well. Customers like it. Improvements needed.
#
# === CRITIQUE ===
# Accuracy: No measurable data or performance metrics provided.
# Specificity: Uses vague adjective 'good' with no detail.
# Audience Alignment: Not tailored to product managers or strategic decisions.
# Length Constraint: Within limit, but lacks meaningful content.
# Formatting Requirement: Not formatted as bullet points.
# Actionability: No specific next steps mentioned.
#
# === AFTER SUMMARY ===
#
# - Product achieved 99.2% uptime last quarter, exceeding SLA targets.
# - Net Promoter Score improved to +25, indicating strong user satisfaction.
# - Primary feedback highlights onboarding friction and mobile performance gaps.
# - Next step: prioritize onboarding redesign and measure conversion lift.
#
#
# === CHANGES MADE ===
# 1. Replaced vague wording ('good') with measurable performance metrics.
# ...
